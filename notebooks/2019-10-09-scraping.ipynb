# %%
import urllib
from bs4 import BeautifulSoup
import pandas as pd

# %%
class Scraper(object): 
    def __init__ (self, site_url, table_url, mtg_type = None):
        self.site_url = site_url
        self.table_url = table_url
        self.mtg_type = mtg_type
        self.table_html = None
        self.table_page = None
        self.table_data = None
        self.next_table_url = None
        self.data_headers = [
            'city',
            'committee',
            'date',
            'doc_type',
            'url',
            'local_path_pdf',
            'local_path_txt'
        ]
        
    def scrape(self):
        self.read_table_page()
        self.parse_table_html()
        self.data = self.convert_table_data()
        
    def run(self):
        # on a loop
        self.scrape()
        self.update_files()
        pass
    
    def update_files():
        pass
        
    def read_table_page(self):
        with urllib.request.urlopen(self.table_url) as f:
            self.table_page = f.read()
        self.table_html = BeautifulSoup(self.table_page)
        
    def build_url(self, x):
        if x.a:
            return self.site_url + x.a["href"]

# %%
class GridleyScraper(Scraper):
            
    def parse_table_html(self):
        table_of_docs = self.table_html.body.find('table', attrs={'class': 'table-responsve'})
        table_headers = [x.text for x in table_of_docs.find_all('th')]
        table_rows = table_of_docs.tbody.find_all('tr')
        table_data = {h: [] for h in table_headers}
        for row in table_rows:
            elements = row.find_all('td')
            for i, h in enumerate(table_headers):
                element = elements[i]
                table_data[h].append(element)
        self.table_data = pd.DataFrame(table_data)

    def convert_table_data(self):
        def split_date_and_name(x):
            words = x.split(" ")
            return " ".join(words[:3]), " ".join(words[3:])
        def parse_table_row(df):
            date_and_name = df["Date"].text
            meeting_date, meeting_type = split_date_and_name(date_and_name)
            cancelled = "cancel" in meeting_type
            agenda_elem = df["Agenda"]
            minutes_elem = df["Minutes"]
            return meeting_date, cancelled, self.build_url(agenda_elem), self.build_url(minutes_elem)
        data = pd.DataFrame({"id": range(0, self.table_data.shape[0])})
        data["Date"], data["Meeting cancelled?"], data["Agenda"], data["Minutes"] = zip(*self.table_data.apply(parse_table_row, axis=1))
        data["Type"] = self.mtg_type
        return data

# %%
gridley_cc_scraper.data
# Out:
#     id                Date  Meeting cancelled?  \
# 0    0     October 7, 2019               False
# 1    1  September 16, 2019               False
# 2    2   September 3, 2019               False
# 3    3     August 19, 2019               False
# 4    4      August 5, 2019               False
# 5    5        July 1, 2019               False
# 6    6       June 17, 2019               False
# 7    7        June 3, 2019               False
# 8    8        June 3, 2019               False
# 9    9        May 20, 2019               False
# 10  10         May 6, 2019               False
# 11  11      April 15, 2019               False
# 12  12       April 1, 2019               False
# 13  13      March 18, 2019               False
# 14  14       March 4, 2019               False
# 15  15   February 19, 2019               False
# 16  16    February 4, 2019               False
# 17  17     January 7, 2019               False
# 18  18   December 28, 2018               False
# 19  19   December 17, 2018               False
# 20  20    December 3, 2018               False
# 21  21   November 19, 2018               False
# 22  22    October 23, 2018               False
# 23  23     October 1, 2018               False
# 24  24  September 17, 2018               False
# 25  25   September 4, 2018               False
# 26  26      August 6, 2018               False
# 27  27       July 16, 2018               False
# 28  28       June 25, 2018               False
# 29  29       June 21, 2018               False
# 30  30       June 18, 2018               False
# 31  31        June 4, 2018               False
# 32  32         May 7, 2018               False
# 33  33      April 16, 2018               False
# 34  34       April 2, 2018               False
# 35  35      March 19, 2018               False
# 36  36       March 5, 2018               False
# 37  37   February 28, 2018               False
# 38  38    February 5, 2018               False
# 39  39    January 16, 2018               False
# 40  40   December 18, 2017               False
# 41  41   November 20, 2017               False
# 42  42    November 6, 2017               False
# 43  43    October 16, 2017               False
# 44  44     October 2, 2017               False
# 45  45  September 18, 2017               False
# 46  46     August 21, 2017               False
# 47  47      August 7, 2017               False
# 48  48       July 17, 2017               False
#
#                                                Agenda  \
# 0   http://gridley.ca.us/public/uploads/pdfs/10-7-...
# 1   http://gridley.ca.us/public/uploads/pdfs/9-16-...
# 2   http://gridley.ca.us/public/uploads/pdfs/9-3-1...
# 3   http://gridley.ca.us/public/uploads/pdfs/8-19-...
# 4   http://gridley.ca.us/public/uploads/pdfs/8-5-1...
# 5   http://gridley.ca.us/public/uploads/pdfs/7-1-1...
# 6   http://gridley.ca.us/public/uploads/pdfs/6-17-...
# 7   http://gridley.ca.us/public/uploads/pdfs/6-3-1...
# 8                                                None
# 9   http://gridley.ca.us/public/uploads/pdfs/5-20-...
# 10  http://gridley.ca.us/public/uploads/pdfs/5-6-1...
# 11  http://gridley.ca.us/public/uploads/pdfs/4-15-...
# 12  http://gridley.ca.us/public/uploads/pdfs/4-1-1...
# 13  http://gridley.ca.us/public/uploads/pdfs/3-18-...
# 14  http://gridley.ca.us/public/uploads/pdfs/3-4-1...
# 15  http://gridley.ca.us/public/uploads/pdfs/Amend...
# 16  http://gridley.ca.us/public/uploads/pdfs/2-4-1...
# 17  http://gridley.ca.us/public/uploads/pdfs/1-7-1...
# 18  http://gridley.ca.us/public/uploads/pdfs/12-28...
# 19  http://gridley.ca.us/public/uploads/pdfs/12-17...
# 20  http://gridley.ca.us/public/uploads/pdfs/12-3-...
# 21  http://gridley.ca.us/public/uploads/pdfs/11-19...
# 22  http://gridley.ca.us/public/uploads/pdfs/10-23...
# 23  http://gridley.ca.us/public/uploads/pdfs/10-1-...
# 24  http://gridley.ca.us/public/uploads/pdfs/9-17-...
# 25  http://gridley.ca.us/public/uploads/pdfs/9-4-1...
# 26  http://gridley.ca.us/public/uploads/pdfs/8-6-1...
# 27  http://gridley.ca.us/public/uploads/pdfs/7-16-...
# 28  http://gridley.ca.us/public/uploads/pdfs/6-25-...
# 29  http://gridley.ca.us/public/uploads/pdfs/6-21-...
# 30  http://gridley.ca.us/public/uploads/pdfs/6-18-...
# 31  http://gridley.ca.us/public/uploads/pdfs/Counc...
# 32  http://gridley.ca.us/public/uploads/pdfs/5-7-1...
# 33  http://gridley.ca.us/public/uploads/pdfs/4-16-...
# 34  http://gridley.ca.us/public/uploads/pdfs/4-2-1...
# 35  http://gridley.ca.us/public/uploads/pdfs/3-19-...
# 36  http://gridley.ca.us/public/uploads/pdfs/3-5-1...
# 37  http://gridley.ca.us/public/uploads/pdfs/2-28-...
# 38  http://gridley.ca.us/public/uploads/pdfs/2-5-1...
# 39  http://gridley.ca.us/public/uploads/pdfs/1-16-...
# 40  http://gridley.ca.us/public/uploads/pdfs/12-18...
# 41  http://gridley.ca.us/public/uploads/pdfs/11-20...
# 42  http://gridley.ca.us/public/uploads/pdfs/11-6-...
# 43  http://gridley.ca.us/public/uploads/pdfs/10-16...
# 44  http://gridley.ca.us/public/uploads/pdfs/10-2-...
# 45  http://gridley.ca.us/public/uploads/pdfs/9-18-...
# 46  http://gridley.ca.us/public/uploads/pdfs/8-21-...
# 47  http://gridley.ca.us/public/uploads/pdfs/8-7-1...
# 48  http://gridley.ca.us/public/uploads/pdfs/7-17-...
#
#                                               Minutes          Type
# 0                                                None  City Council
# 1   http://gridley.ca.us/public/uploads/pdfs/9-16-...  City Council
# 2   http://gridley.ca.us/public/uploads/pdfs/9-3-1...  City Council
# 3   http://gridley.ca.us/public/uploads/pdfs/8-19-...  City Council
# 4   http://gridley.ca.us/public/uploads/pdfs/8-5-1...  City Council
# 5   http://gridley.ca.us/public/uploads/pdfs/7-1-1...  City Council
# 6   http://gridley.ca.us/public/uploads/pdfs/6-17-...  City Council
# 7   http://gridley.ca.us/public/uploads/pdfs/6-3-1...  City Council
# 8                                                None  City Council
# 9   http://gridley.ca.us/public/uploads/pdfs/5-20-...  City Council
# 10  http://gridley.ca.us/public/uploads/pdfs/5-6-1...  City Council
# 11  http://gridley.ca.us/public/uploads/pdfs/4-15-...  City Council
# 12  http://gridley.ca.us/public/uploads/pdfs/4-1-1...  City Council
# 13  http://gridley.ca.us/public/uploads/pdfs/3-18-...  City Council
# 14  http://gridley.ca.us/public/uploads/pdfs/3-4-1...  City Council
# 15  http://gridley.ca.us/public/uploads/pdfs/2-19-...  City Council
# 16  http://gridley.ca.us/public/uploads/pdfs/2-4-1...  City Council
# 17  http://gridley.ca.us/public/uploads/pdfs/1-7-1...  City Council
# 18  http://gridley.ca.us/public/uploads/pdfs/12-28...  City Council
# 19  http://gridley.ca.us/public/uploads/pdfs/12-17...  City Council
# 20  http://gridley.ca.us/public/uploads/pdfs/12-3-...  City Council
# 21  http://gridley.ca.us/public/uploads/pdfs/11-19...  City Council
# 22  http://gridley.ca.us/public/uploads/pdfs/10-23...  City Council
# 23  http://gridley.ca.us/public/uploads/pdfs/10-1-...  City Council
# 24  http://gridley.ca.us/public/uploads/pdfs/9-17-...  City Council
# 25  http://gridley.ca.us/public/uploads/pdfs/9-4-1...  City Council
# 26  http://gridley.ca.us/public/uploads/pdfs/8-6-1...  City Council
# 27  http://gridley.ca.us/public/uploads/pdfs/7-16-...  City Council
# 28  http://gridley.ca.us/public/uploads/pdfs/6-25-...  City Council
# 29  http://gridley.ca.us/public/uploads/pdfs/6-21-...  City Council
# 30  http://gridley.ca.us/public/uploads/pdfs/6-18-...  City Council
# 31  http://gridley.ca.us/public/uploads/pdfs/6-4-1...  City Council
# 32  http://gridley.ca.us/public/uploads/pdfs/5-7-1...  City Council
# 33  http://gridley.ca.us/public/uploads/pdfs/4-16-...  City Council
# 34  http://gridley.ca.us/public/uploads/pdfs/4-2-1...  City Council
# 35  http://gridley.ca.us/public/uploads/pdfs/3-19-...  City Council
# 36  http://gridley.ca.us/public/uploads/pdfs/3-5-1...  City Council
# 37  http://gridley.ca.us/public/uploads/pdfs/2-28-...  City Council
# 38  http://gridley.ca.us/public/uploads/pdfs/2-5-1...  City Council
# 39  http://gridley.ca.us/public/uploads/pdfs/1-16-...  City Council
# 40  http://gridley.ca.us/public/uploads/pdfs/12-18...  City Council
# 41  http://gridley.ca.us/public/uploads/pdfs/11-20...  City Council
# 42  http://gridley.ca.us/public/uploads/pdfs/11-6-...  City Council
# 43  http://gridley.ca.us/public/uploads/pdfs/10-16...  City Council
# 44  http://gridley.ca.us/public/uploads/pdfs/10-2-...  City Council
# 45  http://gridley.ca.us/public/uploads/pdfs/9-18-...  City Council
# 46  http://gridley.ca.us/public/uploads/pdfs/8-21-...  City Council
# 47  http://gridley.ca.us/public/uploads/pdfs/8-7-1...  City Council
# 48  http://gridley.ca.us/public/uploads/pdfs/7-17-...  City Council

# %%
class GridleyScraper(Scraper):
            
    def parse_table_html(self):
        table_of_docs = self.table_html.body.find('table', attrs={'class': 'table-responsve'})
        table_headers = [x.text for x in table_of_docs.find_all('th')]
        table_rows = table_of_docs.tbody.find_all('tr')
        table_data = {h: [] for h in table_headers}
        for row in table_rows:
            elements = row.find_all('td')
            for i, h in enumerate(table_headers):
                element = elements[i]
                table_data[h].append(element)
        self.table_data = pd.DataFrame(table_data)

    def convert_table_data(self):
        def split_date_and_name(x):
            words = x.split(" ")
            return " ".join(words[:3]), " ".join(words[3:])
        def parse_table_row(df):
            date_and_name = df["Date"].text
            meeting_date, meeting_type = split_date_and_name(date_and_name)
            cancelled = "cancel" in meeting_type
            agenda_elem = df["Agenda"]
            minutes_elem = df["Minutes"]
            doc_types = ["Agenda", "Minutes"]
            return pd.Series({
                "city": "Gridley",
                "committee": self.mtg_type,
                "date": meeting_date,
                "doc_type": doc_types,
                'url': [self.build_url(df[x]) for x in doc_types]})
        print(self.table_data.apply(parse_table_row, axis=1))

gridley_cc_scraper = GridleyScraper(
    site_url = "http://gridley.ca.us",
    mtg_type = "City Council",
    table_url = "http://gridley.ca.us/government-and-departments/city-council/")
print(gridley_cc_scraper.data)
# Out:
#                                                     0  \
# 0   city                 Gridley
# committee       C...
# 1   city                    Gridley
# committee     ...
# 2   city                   Gridley
# committee      ...
# 3   city                 Gridley
# committee       C...
# 4   city                Gridley
# committee      Cit...
# 5   city              Gridley
# committee    City Co...
# 6   city               Gridley
# committee     City ...
# 7   city              Gridley
# committee    City Co...
# 8   city              Gridley
# committee    City Co...
# 9   city              Gridley
# committee    City Co...
# 10  city              Gridley
# committee    City Co...
# 11  city                Gridley
# committee      Cit...
# 12  city               Gridley
# committee     City ...
# 13  city                Gridley
# committee      Cit...
# 14  city               Gridley
# committee     City ...
# 15  city                   Gridley
# committee      ...
# 16  city                  Gridley
# committee       ...
# 17  city                 Gridley
# committee       C...
# 18  city                   Gridley
# committee      ...
# 19  city                   Gridley
# committee      ...
# 20  city                  Gridley
# committee       ...
# 21  city                   Gridley
# committee      ...
# 22  city                  Gridley
# committee       ...
# 23  city                 Gridley
# committee       C...
# 24  city                    Gridley
# committee     ...
# 25  city                   Gridley
# committee      ...
# 26  city                Gridley
# committee      Cit...
# 27  city               Gridley
# committee     City ...
# 28  city               Gridley
# committee     City ...
# 29  city               Gridley
# committee     City ...
# 30  city               Gridley
# committee     City ...
# 31  city              Gridley
# committee    City Co...
# 32  city              Gridley
# committee    City Co...
# 33  city                Gridley
# committee      Cit...
# 34  city               Gridley
# committee     City ...
# 35  city                Gridley
# committee      Cit...
# 36  city               Gridley
# committee     City ...
# 37  city                   Gridley
# committee      ...
# 38  city                  Gridley
# committee       ...
# 39  city                  Gridley
# committee       ...
# 40  city                   Gridley
# committee      ...
# 41  city                   Gridley
# committee      ...
# 42  city                  Gridley
# committee       ...
# 43  city                  Gridley
# committee       ...
# 44  city                 Gridley
# committee       C...
# 45  city                    Gridley
# committee     ...
# 46  city                 Gridley
# committee       C...
# 47  city                Gridley
# committee      Cit...
# 48  city               Gridley
# committee     City ...
#
#                                                     1
# 0   city                 Gridley
# committee       C...
# 1   city                    Gridley
# committee     ...
# 2   city                   Gridley
# committee      ...
# 3   city                 Gridley
# committee       C...
# 4   city                Gridley
# committee      Cit...
# 5   city              Gridley
# committee    City Co...
# 6   city               Gridley
# committee     City ...
# 7   city              Gridley
# committee    City Co...
# 8   city              Gridley
# committee    City Co...
# 9   city              Gridley
# committee    City Co...
# 10  city              Gridley
# committee    City Co...
# 11  city                Gridley
# committee      Cit...
# 12  city               Gridley
# committee     City ...
# 13  city                Gridley
# committee      Cit...
# 14  city               Gridley
# committee     City ...
# 15  city                   Gridley
# committee      ...
# 16  city                  Gridley
# committee       ...
# 17  city                 Gridley
# committee       C...
# 18  city                   Gridley
# committee      ...
# 19  city                   Gridley
# committee      ...
# 20  city                  Gridley
# committee       ...
# 21  city                   Gridley
# committee      ...
# 22  city                  Gridley
# committee       ...
# 23  city                 Gridley
# committee       C...
# 24  city                    Gridley
# committee     ...
# 25  city                   Gridley
# committee      ...
# 26  city                Gridley
# committee      Cit...
# 27  city               Gridley
# committee     City ...
# 28  city               Gridley
# committee     City ...
# 29  city               Gridley
# committee     City ...
# 30  city               Gridley
# committee     City ...
# 31  city              Gridley
# committee    City Co...
# 32  city              Gridley
# committee    City Co...
# 33  city                Gridley
# committee      Cit...
# 34  city               Gridley
# committee     City ...
# 35  city                Gridley
# committee      Cit...
# 36  city               Gridley
# committee     City ...
# 37  city                   Gridley
# committee      ...
# 38  city                  Gridley
# committee       ...
# 39  city                  Gridley
# committee       ...
# 40  city                   Gridley
# committee      ...
# 41  city                   Gridley
# committee      ...
# 42  city                  Gridley
# committee       ...
# 43  city                  Gridley
# committee       ...
# 44  city                 Gridley
# committee       C...
# 45  city                    Gridley
# committee     ...
# 46  city                 Gridley
# committee       C...
# 47  city                Gridley
# committee      Cit...
# 48  city               Gridley
# committee     City ...
# None

# %%
# gridley_cc_scraper.data

# %%
class BiggsScraper(Scraper): 
        
    def scrape(self):
        while self.table_url != self.next_table_url:
            if self.next_table_url:
                self.table_url = self.next_table_url
            self.read_table_page()
            self.parse_table_html()
            self.data = self.convert_table_data()
    
    def parse_table_html(self):
        table_of_docs = self.table_html.body.find('table')
        table_headers = [x.text.strip() for x in table_of_docs.find("tr").find_all("td")]
        table_rows = table_of_docs.tbody.find_all('tr')[1:]
        table_data = {h: [] for h in table_headers}
        for row in table_rows:
            elements = row.find_all('td')
            if len(elements) == len(table_headers):
                for i, h in enumerate(table_headers):
                    element = elements[i]
                    table_data[h].append(element)
            else:
                print("next url to lookup: ", self.build_url(elements[0]))
                self.next_table_url = self.build_url(elements[0])
        self.table_data = pd.DataFrame(table_data)

    def convert_table_data(self):
        def split_date_and_name(x):
            words = x.split(" ")
            return " ".join(words[:3]), " ".join(words[3:])
        def parse_table_row(df):
            date = df["Meeting Date"].text.strip()
            time = df["Time"].text.strip()
            if "Type" in df:
                mtg_type = df["Type"].text.strip()
            elif "TYpe" in df:
                mtg_type = df["TYpe"].text.strip()
            else:
                mtg_type = ""
            cancelled = "cancel" in mtg_type.lower()
            if cancelled:
                mtg_type = mtg_type[11:]
            agenda_elem = df["Agendas"]
            minutes_elem = df["Minutes"]
            return date, time, mtg_type, cancelled, self.build_url(agenda_elem), self.build_url(minutes_elem)
        data = pd.DataFrame({"id": range(0, self.table_data.shape[0])})
        data["Date"], data["Time"], data["Type"], data["Meeting cancelled?"], data["Agenda"], data["Minutes"] = zip(*self.table_data.apply(parse_table_row, axis=1))
        return data

biggs_scraper = BiggsScraper(
    site_url = "https://www.biggs-ca.gov/",
#     table_url = "https://www.biggs-ca.gov/Government/Agendas--Minutes/index.html")
    table_url = "https://www.biggs-ca.gov/Government/Agendas--Minutes/2009-Agendas--Minutes/index.html")
# Out:
# next url to lookup:  https://www.biggs-ca.gov/Government/Agendas--Minutes/2008-Agendas--Minutes/index.html

# %%
# biggs_scraper.data

# %%
table_url = "http://liveoakca.iqm2.com/Citizens/Calendar.aspx?From=1/1/1900&To=12/31/9999"
with urllib.request.urlopen(table_url) as f:
    table_page = f.read()
table_html = BeautifulSoup(table_page)

# %%
site_url = "http://liveoakca.iqm2.com/Citizens/"
        
def build_url(x):
    if x.a:
        return site_url + x.a["href"]
    
table_data = []
        
month = None
year = None
rows = table_html.find("div", {"id": "ContentPlaceholder1_pnlMeetings"}).find_all("div", {"class": "Row"})
for row in rows:
    if "MonthHeader" in row["class"]:
        month, year = row.text.strip().split(", ")
    elif "MeetingRow" in row["class"]:
        cancelled = False
        links = {}
        for row_part in row.find_all("div", recursive=False):
            for div in row_part.find_all("div", recursive=False):
                if "RowIcon" in div["class"]:
                    pass
                elif "RowLink" in div["class"]:
                    # title of RowLink has lots of info
                    links["mtg_page"] = build_url(div)
                    date = div.text.strip()
                elif "MeetingLinks" in div["class"]:
                    for link in div.find_all("div"):
                        doc_type = div.a.text.strip()
                        partial_url = div.a["href"]
                        if not partial_url in ["javascript:void(0)", "", "#"]:
                            doc_url = build_url(div)
                            links[doc_type] = doc_url
                elif "RowDetails" in div["class"]:
                    mtg_type = div.text.strip()
                    pass
                elif "RowRight" in div["class"]:
                    cancelled = True
        table_data.append((month, year, date, cancelled, links, mtg_type))
table_data = pd.DataFrame(table_data, columns=["Month", "Year", "Date", "Cancelled", "Links", "Type"])
table_data
# Out:
#         Month  Year                  Date  Cancelled  \
# 0    November  2016  Nov 16, 2016 6:00 PM      False
# 1    December  2016   Dec 7, 2016 6:00 PM      False
# 2    December  2016  Dec 21, 2016 6:00 PM      False
# 3     January  2017   Jan 4, 2017 6:00 PM      False
# 4     January  2017          Jan 18, 2017       True
# ..        ...   ...                   ...        ...
# 119   October  2019  Oct 16, 2019 6:00 PM      False
# 120  November  2019   Nov 6, 2019 6:00 PM      False
# 121  November  2019  Nov 20, 2019 6:00 PM      False
# 122  December  2019   Dec 4, 2019 6:00 PM      False
# 123  December  2019  Dec 18, 2019 6:00 PM      False
#
#                                                  Links  \
# 0    {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
# 1    {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
# 2    {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
# 3    {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
# 4    {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
# ..                                                 ...
# 119  {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
# 120  {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
# 121  {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
# 122  {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
# 123  {'mtg_page': 'http://liveoakca.iqm2.com/Citize...
#
#                                Type
# 0    City Council - Regular Meeting
# 1    City Council - Regular Meeting
# 2    City Council - Regular Meeting
# 3    City Council - Regular Meeting
# 4    City Council - Regular Meeting
# ..                              ...
# 119  City Council - Regular Meeting
# 120  City Council - Regular Meeting
# 121  City Council - Regular Meeting
# 122  City Council - Regular Meeting
# 123  City Council - Regular Meeting
#
# [124 rows x 6 columns]

# %%
def parse_table_row(df):
    agenda = None
    minutes = None
    links = df["Links"]
    if "Agenda" in links:
        agenda = links["Agenda"]
    if "Minutes" in links:
        minutes = links["Minutes"]
    return df["Date"], df["Cancelled"], agenda, minutes, df["Type"]
data = pd.DataFrame({"id": range(0, table_data.shape[0])})
data["Date"], data["Meeting cancelled?"], data["Agenda"], data["Minutes"], data["Type"] = zip(*table_data.apply(parse_table_row, axis=1))
# return data
data
# Out:
#       id                  Date  Meeting cancelled?  \
# 0      0  Nov 16, 2016 6:00 PM               False
# 1      1   Dec 7, 2016 6:00 PM               False
# 2      2  Dec 21, 2016 6:00 PM               False
# 3      3   Jan 4, 2017 6:00 PM               False
# 4      4          Jan 18, 2017                True
# ..   ...                   ...                 ...
# 119  119  Oct 16, 2019 6:00 PM               False
# 120  120   Nov 6, 2019 6:00 PM               False
# 121  121  Nov 20, 2019 6:00 PM               False
# 122  122   Dec 4, 2019 6:00 PM               False
# 123  123  Dec 18, 2019 6:00 PM               False
#
#                                                 Agenda Minutes  \
# 0    http://liveoakca.iqm2.com/Citizens/FileOpen.as...    None
# 1    http://liveoakca.iqm2.com/Citizens/FileOpen.as...    None
# 2    http://liveoakca.iqm2.com/Citizens/FileOpen.as...    None
# 3    http://liveoakca.iqm2.com/Citizens/FileOpen.as...    None
# 4                                                 None    None
# ..                                                 ...     ...
# 119                                               None    None
# 120                                               None    None
# 121                                               None    None
# 122                                               None    None
# 123                                               None    None
#
#                                Type
# 0    City Council - Regular Meeting
# 1    City Council - Regular Meeting
# 2    City Council - Regular Meeting
# 3    City Council - Regular Meeting
# 4    City Council - Regular Meeting
# ..                              ...
# 119  City Council - Regular Meeting
# 120  City Council - Regular Meeting
# 121  City Council - Regular Meeting
# 122  City Council - Regular Meeting
# 123  City Council - Regular Meeting
#
# [124 rows x 6 columns]

# %%
class LiveOaksScraper(Scraper):
            
    def parse_table_html(self):
        table_data = []

        month = None
        year = None
        rows = self.table_html.find("div", {"id": "ContentPlaceholder1_pnlMeetings"}).find_all("div", {"class": "Row"})
        for row in rows:
            if "MonthHeader" in row["class"]:
                month, year = row.text.strip().split(", ")
            elif "MeetingRow" in row["class"]:
                cancelled = False
                links = {}
                date = None
                mtg_type = None
                for row_part in row.find_all("div", recursive=False):
                    for div in row_part.find_all("div", recursive=False):
                        if "RowIcon" in div["class"]:
                            pass
                        elif "RowLink" in div["class"]:
                            # title of RowLink has lots of info
                            links["mtg_page"] = self.build_url(div)
                            date = div.text.strip()
                        elif "MeetingLinks" in div["class"]:
                            for link in div.find_all("div"):
                                doc_type = div.a.text.strip()
                                partial_url = div.a["href"]
                                if not partial_url in ["javascript:void(0)", "", "#"]:
                                    doc_url = self.build_url(div)
                                    links[doc_type] = doc_url
                        elif "RowDetails" in div["class"]:
                            mtg_type = div.text.strip()
                            pass
                        elif "RowRight" in div["class"]:
                            cancelled = True
                table_data.append((month, year, cancelled, links, mtg_type, date))
        table_data = pd.DataFrame(table_data, columns=["Month", "Year", "Cancelled", "Links", "Type", "Date"])
        self.table_data = table_data

    def convert_table_data(self):
        def parse_table_row(df):
            agenda = None
            minutes = None
            links = df["Links"]
            if "Agenda" in links:
                agenda = links["Agenda"]
            if "Minutes" in links:
                minutes = links["Minutes"]
            return df["Date"], df["Cancelled"], agenda, minutes, df["Type"]
        data = pd.DataFrame({"id": range(0, self.table_data.shape[0])})
        data["Date"], data["Meeting cancelled?"], data["Agenda"], data["Minutes"], data["Type"] = zip(*self.table_data.apply(parse_table_row, axis=1))
        return data
    
live_oaks_scraper = LiveOaksScraper(
    site_url = "http://liveoakca.iqm2.com/Citizens/",
    table_url = "http://liveoakca.iqm2.com/Citizens/Calendar.aspx?From=1/1/1900&To=12/31/9999")

# %%
# live_oaks_scraper.data
# Out:
#       id                  Date  Meeting cancelled?  \
# 0      0  Nov 16, 2016 6:00 PM               False
# 1      1   Dec 7, 2016 6:00 PM               False
# 2      2  Dec 21, 2016 6:00 PM               False
# 3      3   Jan 4, 2017 6:00 PM               False
# 4      4          Jan 18, 2017                True
# ..   ...                   ...                 ...
# 119  119  Oct 16, 2019 6:00 PM               False
# 120  120   Nov 6, 2019 6:00 PM               False
# 121  121  Nov 20, 2019 6:00 PM               False
# 122  122   Dec 4, 2019 6:00 PM               False
# 123  123  Dec 18, 2019 6:00 PM               False
#
#                                                 Agenda Minutes  \
# 0    http://liveoakca.iqm2.com/Citizens/FileOpen.as...    None
# 1    http://liveoakca.iqm2.com/Citizens/FileOpen.as...    None
# 2    http://liveoakca.iqm2.com/Citizens/FileOpen.as...    None
# 3    http://liveoakca.iqm2.com/Citizens/FileOpen.as...    None
# 4                                                 None    None
# ..                                                 ...     ...
# 119                                               None    None
# 120                                               None    None
# 121                                               None    None
# 122                                               None    None
# 123                                               None    None
#
#                                Type
# 0    City Council - Regular Meeting
# 1    City Council - Regular Meeting
# 2    City Council - Regular Meeting
# 3    City Council - Regular Meeting
# 4    City Council - Regular Meeting
# ..                              ...
# 119  City Council - Regular Meeting
# 120  City Council - Regular Meeting
# 121  City Council - Regular Meeting
# 122  City Council - Regular Meeting
# 123  City Council - Regular Meeting
#
# [124 rows x 6 columns]

# %%
table_url = "https://www.hillsborough.net/DocumentCenter/"
# HillsboroughScraper

# %%
def init_srapers():
    return [
        GridleyScraper(
            site_url = "http://gridley.ca.us",
            mtg_type = "City Council",
            table_url = "http://gridley.ca.us/government-and-departments/city-council/"),
        GridleyScraper(
            site_url = "http://gridley.ca.us",
            mtg_type = "Planning Commission",
            table_url = "http://gridley.ca.us/government-and-departments/planning-commission/"),
        BiggsScraper(
            site_url = "https://www.biggs-ca.gov/",
            table_url = "https://www.biggs-ca.gov/Government/Agendas--Minutes/index.html"),
#             table_url = "https://www.biggs-ca.gov/Government/Agendas--Minutes/2009-Agendas--Minutes/index.html")
         LiveOaksScraper(
            site_url = "http://liveoakca.iqm2.com/Citizens/",
            table_url = "http://liveoakca.iqm2.com/Citizens/Calendar.aspx?From=1/1/1900&To=12/31/9999")
    ]
