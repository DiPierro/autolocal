# %%
import tabula
from autolocal.pdf2txt import pdf2txt

# %%
pdf_path = '../data/docs/agenda_packet.pdf'
txt_path = '../data/docs/agenda_packet.txt'

# %%
args = [pdf_path, '-o', txt_path]
pdf2txt(args)
# Out:
# 0

# %%
tabula.read_pdf(pdf_path, pages=7, lattice=True)
# Out:
#     Req #                                              Title  Status  \
# 0   17163                             Assistant City Manager  Filled
# 1   17162  Assistant Director of Public\rWorks/City Engineer  Filled
# 2   17159                                Director of Finance  Filled
# 3   17168                           Director of Public Works  Filled
# 4   17161               Director of Water & Sewer\rUtilities  Filled
# 5   17169                        Street Maintenance Worker I  Filled
# 6   17171                        Electric Maintenance Worker  Filled
# 7   17172                        Community Service Officer I  Filled
# 8   17175                        Community Service Officer I  Filled
# 9   17174                        Street Maintenance Worker I  Filled
# 10  17178                            Automotive Technician I  Filled
# 11  17179                        Code Enforcement Technician  Filled
# 12  17181                                 Management Analyst  Filled
# ...

# %%
# ?tabula.read_pdf
