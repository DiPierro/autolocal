# %%
# class Scraper(object): 
#     def __init__ (self):
#         self.baseURL = "http://gridley.ca.us/government-and-departments/city-council/"

#     def scrape(self):

# %%
import urllib

from lxml import html

# %%
baseURL = "http://gridley.ca.us/government-and-departments/city-council/"
with urllib.request.urlopen(baseURL) as f:
    string = f.read()

# %%
string
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n\t<meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<link rel="icon" type="image/png" href="/public/uploads/images/favicon.png">\n<title>Gridley City Council | City of Gridley</title>\n<meta name=\'keywords\' content=\'\' />\n<meta name=\'description\' content=\'A small town that loves company\' />\n<link rel=\'canonical\' href=\'http://gridley.ca.us/index.php/government-and-departments/city-council/\' />\n<!-- generated by seo_lite -->\n<link rel="stylesheet" href="/assets/css/bootstrap.css">\n<link rel="stylesheet" href="/assets/css/main.css">\n<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css">\n<link href="https://fonts.googleapis.com/css?family=Bree+Serif%7cOpen+Sans:300,400,600,700,800" rel="stylesheet"> \n<script src="/assets/js/jquery-1.11.2.min.js"></script>\n<script src="/assets/js/bootstrap.min.js"></script>\n<script src="/assets/js/jquery
# ...

# %%
xml.parse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2ebb81030233> in <module>
# ----> 1 xml.parse
#
# NameError: name 'xml' is not defined

# %%
tree = html.fromstring(string)
tree.find("body").xpath("//[@class='table-responsve']")
# Out:
# ---------------------------------------------------------------------------
# XPathEvalError                            Traceback (most recent call last)
# <ipython-input-17-9c6d5ae5d2a1> in <module>
#       1 tree = html.fromstring(string)
# ----> 2 tree.find("body").xpath("//[@class='table-responsve']")
#
# src/lxml/etree.pyx in lxml.etree._Element.xpath()
#
# src/lxml/xpath.pxi in lxml.etree.XPathElementEvaluator.__call__()
#
# src/lxml/xpath.pxi in lxml.etree._XPathEvaluatorBase._handle_result()
#
# XPathEvalError: Invalid expression
