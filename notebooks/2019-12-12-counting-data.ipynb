# %%
import pandas as pd

# %%
metadata_path = '../data/index/metadata.csv'

# %%
df = pd.read_csv(metadata_path)

# %%
df.loc[:,'committee'].unique()
# Out:
# array(['Legislative Review Committee', 'Planning Commission',
#        'Administrative Hearing', 'Sustainability Commission',
#        'Teen Commission', 'Audit Committee', 'Design Review Committee',
#        'Environmental Review Committee', 'Bicycle Pedestrian Commission',
#        'City Council', 'Public Safety Commission', 'Housing Commission',
#        'Parks and Recreation Commission', 'Library Commission', 'TICC',
#        'Fine Arts Commission', 'Disaster Council',
#        'Economic Development Committee',
#        'Fiscal Strategic Plan Committee',
#        'Parks & Rec. and Bicycle Ped. Commissions',
#        'Council Sustainability Committee',
#        'Keep Hayward Clean and Green Task Force',
#        'Council Infrastructure Committee',
#        'Homelessness-Housing Task Force', 'Hayward Youth Commission',
#        'Community Services Commission',
#        'Hayward Local Agencies Committee',
#        'Hayward Area Shoreline Planning Agency',
# ...
